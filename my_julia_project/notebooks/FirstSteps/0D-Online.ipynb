# %%
import Pkg; 
Pkg.activate(".."); Pkg.instantiate();
using RxInfer, Random, Plots, StableRNGs
# Out:
#   Activating project at `/ws`
# ┌ Warning: The active manifest file is an older format with no julia version entry. Dependencies may have been resolved with a different julia version.
# └ @ nothing /ws/Manifest.toml:0

# %% [markdown]
# #### Data Generation

# %%
s_init = [1, 0]
rng = StableRNG(42)
# Out:
# StableRNGs.LehmerRNG(state=0x00000000000000000000000000000055)

# %%
function rand_vec(rng, distribution::Categorical)
  k = ncategories(distribution)
  s = zeros(k)
  drawn_category = rand(rng, distribution)
  s[drawn_category] = 1
  return s
end
# Out:
# rand_vec (generic function with 1 method)

# %%
function generate_data(rng)
  # Emmision probabilities
  emission_prob = [0.7 0.3; 0.3 0.7]

  y_prob_vec = emission_prob * s_init
  y = rand_vec(rng, Categorical(y_prob_vec / sum(y_prob_vec)))

  return y
end

generate_data(rng)
# Out:
# 2-element Vector{Float64}:
#  1.0
#  0.0

# %%
datastream   = RecentSubject(Vector{Float64})
observations = labeled(Val((:y, )), combineLatest(datastream))
# Out:
# LabeledObservable(@NamedTuple{y::Vector{Float64}}, Rocket.CombineLatestObservable{Tuple{Vector{Float64}}, Tuple{Rocket.RecentSubjectInstance{Vector{Float64}, Subject{Vector{Float64}, AsapScheduler, AsapScheduler}}}, PushEach})

# %% [markdown]
# ##### Testing data generation

# %%
test_subscription = subscribe!(observations,
  (new_observation) -> println("Got new obersvation: ", new_observation)
)
# Out:
# CombineLatestSubscription()

# %%
for i in 1:5
  next!(datastream, generate_data(rng))
end
# Out:
# Got new obersvation: (y = [1.0, 0.0],)
# Got new obersvation: (y = [0.0, 1.0],)
# Got new obersvation: (y = [0.0, 1.0],)
# Got new obersvation: (y = [1.0, 0.0],)
# Got new obersvation: (y = [0.0, 1.0],)

# %%
unsubscribe!(test_subscription)

# %% [markdown]
# #### Model

# %%
@model function hidden_markov_model(_s_prev, y)
  A ~ MatrixDirichlet([100 1;
                       1 100])
  B ~ MatrixDirichlet([10 1;
                       1 10])

  s_prev ~ Categorical(_s_prev)

  s ~ Transition(s_prev, A)
  y ~ Transition(s, B)
end

@constraints function hidden_markov_model_constraints()
  q(s, s_prev, B, A) = q(s, s_prev)q(B)q(A)
end 

hidden_markov_model_autoupdates = @autoupdates begin
  _s_prev = params(q(s_prev))
end
# Out:
# @autoupdates begin
#     _s_prev = params(q(s_prev))
# end

# %%
imarginals = @initialization begin
  q(A) = vague(MatrixDirichlet, 2, 2)
  q(B) = vague(MatrixDirichlet, 2, 2)
  q(s) = vague(Categorical, 2)
  q(s_prev) = Categorical(fill(0.5, 2))
  q(y) = vague(Categorical, 2)
end

ireturnvars = (
  A = KeepLast(),
  B = KeepLast(),
  s = KeepLast()
)

engine = infer(
  model          = hidden_markov_model(),
  constraints    = hidden_markov_model_constraints(),
  datastream     = observations,
  autoupdates    = hidden_markov_model_autoupdates,
  initialization = imarginals,
  keephistory    = 100,
  historyvars    = ireturnvars,
  autostart      = false
)
# Out:
# RxInferenceEngine:
#   Posteriors stream    | enabled for (A, s, B, s_prev)
#   Free Energy stream   | disabled
#   Posteriors history   | available for (A, s, B)
#   Free Energy history  | unavailable
#   Enabled events       | [  ]

# %% [markdown]
# #### Inferring

# %%
s_update_subscription = subscribe!(engine.posteriors[:s],
  (new_posterior_s) -> println("New posterior: ", new_posterior_s)
)

RxInfer.start(engine)
# Out:
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.5, 0.5])

# %%
y_history = []
for i in 1:100
  y = generate_data(rng)
  push!(y_history, y)
  println("observation y: ", y)
  next!(datastream, y)
end
# Out:
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.07549735257365202, 0.924502647426348])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.6111707444948147, 0.38882925550518527])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.07876816750085765, 0.9212318324991423])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.0110926915038325, 0.9889073084961675])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.0010964078400304638, 0.9989035921599695])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.00037993639426019094, 0.9996200636057397])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.09466561130296759, 0.9053343886970324])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.04754654284584693, 0.9524534571541531])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.07714414788803219, 0.9228558521119679])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.2390910159729792, 0.7609089840270209])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.6561481376991455, 0.34385186230085446])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9338510901708155, 0.06614890982918448])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.992958106995235, 0.007041893004765063])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9991873984184245, 0.0008126015815754801])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996402174079192, 0.0003597825920807835])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.905630999219682, 0.09436900078031787])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9544873722758309, 0.045512627724169134])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9362715520706252, 0.06372844792937479])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9980831793697166, 0.0019168206302833928])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.999532866812548, 0.0004671331874519461])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9043518367186417, 0.09564816328135833])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9457977568937996, 0.05420224310620027])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.881133808736442, 0.11886619126355807])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.6017934951884774, 0.39820650481152264])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9633972587241255, 0.03660274127587451])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9956024133995574, 0.004397586600442664])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.8483081126651094, 0.15169188733489053])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9952165623521992, 0.004783437647800743])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9992506555922269, 0.0007493444077729998])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996484852922927, 0.0003515147077073208])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.999671102129531, 0.0003288978704690516])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996726231721101, 0.0003273768278898852])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996727193489041, 0.00032728065109596295])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996727255565411, 0.0003272744434589659])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996727259542555, 0.00032727404574445316])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996727259798, 0.0003272740202000702])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9061084226584877, 0.09389157734151223])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9995821169429483, 0.00041788305705169325])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996249918552259, 0.00037500814477406635])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9061031089267942, 0.09389689107320576])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9995821173449742, 0.00041788265502585637])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9075346919367174, 0.09246530806328253])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9995829903914251, 0.00041700960857500076])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9075129538365245, 0.09248704616347546])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9995829771190129, 0.0004170228809870155])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996257078458258, 0.00037429215417425683])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.999672654807866, 0.00032734519213398384])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9061091409404088, 0.09389085905959108])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.999582117385478, 0.0004178826145220841])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996249922214294, 0.00037500777857047676])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9061031089714654, 0.09389689102853462])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9995821173449735, 0.0004178826550265625])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9075346919360354, 0.09246530806396462])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9995829903914245, 0.00041700960857541443])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9075129538365349, 0.09248704616346509])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9995829771190129, 0.0004170228809870091])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996257078458258, 0.0003742921541742517])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.999672654807866, 0.00032734519213398384])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996727019881393, 0.0003272980118607434])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9061084203935034, 0.09389157960649672])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9995821169440522, 0.0004178830559478301])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996249918541207, 0.00037500814587931294])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996726539820601, 0.0003273460179399092])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996727016229081, 0.00032729837709181677])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996727259316249, 0.00032727406837508306])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996727259690521, 0.00032727403094794994])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9061084226665145, 0.09389157733348548])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9995821169436095, 0.00041788305639041645])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996249918552783, 0.00037500814472175094])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996726539820605, 0.0003273460179395083])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996727016229088, 0.00032729837709122685])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996727259316249, 0.00032727406837508257])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9061084230377796, 0.09389157696222045])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9577793886884364, 0.042220611311563586])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9586934645862499, 0.041306535413750026])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996168658896728, 0.00038313411032717256])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.999651810178217, 0.0003481898217829321])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996726862017619, 0.00032731379823817974])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9061087410461307, 0.09389125895386931])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.999582117140096, 0.0004178828599038813])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9075346059193375, 0.09246539408066247])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9995829903391952, 0.00041700966080480874])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996257188836168, 0.0003742811163831651])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996726548205761, 0.0003273451794238632])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996727019937697, 0.00032729800623032003])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9061084203940988, 0.09389157960590115])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9577793879829393, 0.04222061201706068])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9586934644791079, 0.04130653552089203])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996168658896578, 0.00038313411034224753])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996518101781624, 0.0003481898218375673])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996726862017618, 0.0003273137982382178])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996727153037669, 0.00032728469623306594])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996727259554439, 0.00032727404455615945])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9061084228292204, 0.09389157717077957])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9995821169437095, 0.0004178830562905148])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996249918553612, 0.00037500814463880947])
# observation y: [0.0, 1.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996726539820606, 0.0003273460179394123])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9061091519145124, 0.09389084808548755])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.999582117392209, 0.00041788260779090713])
# observation y: [1.0, 0.0]
# New posterior: Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996249922270238, 0.0003750077729762698])

# %%
RxInfer.stop(engine)
unsubscribe!(s_update_subscription)

# %%
s = engine.history[:s]
println(s)

p1 = scatter(argmax.(ReactiveMP.probvec.(s)),
                        title = "Inference Results",
                        label = "Inferred",
                        ms = 6, 
                        legend = :right,
                        xlabel = "Time",
                        yticks = ([1, 2], ["Exists", "Not Exists"]),
                        #size = (900, 500)
                        )

p1 = scatter!(argmax.(y_history),
                        label = "Observation",
                        ms = 3, 
                        )

p = plot(p1)
savefig(p, "figures/0D-online.png")
display(p)
# Out:
# Any[Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.07549735257365202, 0.924502647426348]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.6111707444948147, 0.38882925550518527]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.07876816750085765, 0.9212318324991423]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.0110926915038325, 0.9889073084961675]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.0010964078400304638, 0.9989035921599695]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.00037993639426019094, 0.9996200636057397]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.09466561130296759, 0.9053343886970324]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.04754654284584693, 0.9524534571541531]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.07714414788803219, 0.9228558521119679]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.2390910159729792, 0.7609089840270209]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.6561481376991455, 0.34385186230085446]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9338510901708155, 0.06614890982918448]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.992958106995235, 0.007041893004765063]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9991873984184245, 0.0008126015815754801]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996402174079192, 0.0003597825920807835]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.905630999219682, 0.09436900078031787]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9544873722758309, 0.045512627724169134]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9362715520706252, 0.06372844792937479]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9980831793697166, 0.0019168206302833928]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.999532866812548, 0.0004671331874519461]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9043518367186417, 0.09564816328135833]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9457977568937996, 0.05420224310620027]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.881133808736442, 0.11886619126355807]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.6017934951884774, 0.39820650481152264]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9633972587241255, 0.03660274127587451]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9956024133995574, 0.004397586600442664]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.8483081126651094, 0.15169188733489053]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9952165623521992, 0.004783437647800743]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9992506555922269, 0.0007493444077729998]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996484852922927, 0.0003515147077073208]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.999671102129531, 0.0003288978704690516]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996726231721101, 0.0003273768278898852]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996727193489041, 0.00032728065109596295]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996727255565411, 0.0003272744434589659]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996727259542555, 0.00032727404574445316]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9996727259798, 0.0003272740202000702]), Categorical{Float64, Vector{Float64}}(support=Base.OneTo(2), p=[0.9061084226584877, 0.09389157734151223]), Categorical{F ...
